# %%
from data_processor import DataProcessor
from data_reader import DataReader
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
dp = DataProcessor("../lataus/data/lam/")

# %%
dp.read_available_data()

# %%
dp.process_data("./data/")
# Out:
# /lamraw_102_16_1.csv already exists
# /lamraw_102_16_10.csv already exists
# /lamraw_102_16_11.csv already exists
# /lamraw_102_16_12.csv already exists
# /lamraw_102_16_13.csv already exists
# /lamraw_102_16_14.csv already exists
# /lamraw_102_16_15.csv already exists
# /lamraw_102_16_16.csv already exists
# /lamraw_102_16_17.csv already exists
# /lamraw_102_16_18.csv already exists
# /lamraw_102_16_19.csv already exists
# /lamraw_102_16_2.csv already exists
# /lamraw_102_16_20.csv already exists
# /lamraw_102_16_21.csv already exists
# /lamraw_102_16_22.csv already exists
# /lamraw_102_16_23.csv already exists
# /lamraw_102_16_24.csv already exists
# /lamraw_102_16_25.csv already exists
# /lamraw_102_16_26.csv already exists
# /lamraw_102_16_27.csv already exists
# /lamraw_102_16_28.csv already exists
# /lamraw_102_16_29.csv already exists
# /lamraw_102_16_3.csv already exists
# /lamraw_102_16_30.csv already exists
# /lamraw_102_16_31.csv already exists
# ...

# %%
dr = DataReader("data/")

# %%
selected_lam = "102"

combined = dr.combine_dfs(selected_lam)

# %%
import matplotlib.pyplot as plt

# %%
fig, ax = plt.subplots()
rects1 = ax.bar(combined.hour, combined.count_car, label='Suunta 1')

# %%
selected_lam_2 = "104"

combined_2 = dr.combine_dfs(selected_lam_2)

# %%
fig, ax = plt.subplots()
rects1 = ax.bar(combined_2.hour, combined_2.count_car, label='Suunta 1')
